# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings

# This filters out the specific warnings you are seeing
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/rgard/csv_files/Data Visualization/spotify_data_clean.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity  explicit artist_name  artist_popularity  \
# 0             4                 0      True       Diplo                 77
# 1             1                 0      True    Yelawolf                 64
# 2             1                 4      True   Riff Raff                 48
# 3             8                30      True       Diplo                 77
# 4             2                 0      True     Rumelis                 48
#
#    artist_followers                      artist_genres  \
# 0           2812821                         moombahton
# 1           2363438  country hip hop, southern hip hop
# 2            193302                                NaN
# 3           2813710                         moombahton
# 4              8682                           dark r&b
#
#                  album_id                           album_name  \
# 0  5QRFnGnBeMGePBKF2xTz5z                   d00mscrvll, Vol. 1
# 1  4SUmmwnv0xTjRcLdjczGg2                                 OMG!
# 2  3E3zEAL8gUYWaLYB9L7gbp                          Hard 2 Find
# 3  5QRFnGnBeMGePBKF2xTz5z                   d00mscrvll, Vol. 1
# 4  06FDIpSHYmZAZoyuYtc7kd  come closer / ride me like a harley
#
#   album_release_date  album_total_tracks album_type  track_duration_min
# 0         2025-10-31                   9      album                1.55
# 1         2025-10-31                   1     single                3.07
# 2         2025-10-31                   1     single                2.55
# 3         2025-10-31                   9      album                1.69
# 4         2025-10-30                   2     single                2.39

# %%
df.shape
# Out:
# (8582, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8582 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8582 non-null   object
#  1   track_name          8582 non-null   object
#  2   track_number        8582 non-null   int64
#  3   track_popularity    8582 non-null   int64
#  4   explicit            8582 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8582 non-null   int64
#  7   artist_followers    8582 non-null   int64
#  8   artist_genres       5221 non-null   object
#  9   album_id            8582 non-null   object
#  10  album_name          8582 non-null   object
#  11  album_release_date  8582 non-null   object
#  12  album_total_tracks  8582 non-null   int64
#  13  album_type          8582 non-null   object
#  14  track_duration_min  8582 non-null   float64
# dtypes: bool(1), float64(1), int64(5), object(8)
# memory usage: 947.2+ KB

# %%
df.isna().sum()
# Out:
# track_id                 0
# track_name               0
# track_number             0
# track_popularity         0
# explicit                 0
# artist_name              3
# artist_popularity        0
# artist_followers         0
# artist_genres         3361
# album_id                 0
# album_name               0
# album_release_date       0
# album_total_tracks       0
# album_type               0
# track_duration_min       0
# dtype: int64

# %%
df_sorted = df.sort_values(by='track_popularity', ascending = False)
df_sorted.head(10)
# Out:
#                     track_id          track_name  track_number  \
# 457   1CPZ5BxNNd0n0nF4Orb9JS              Golden             4
# 88    3yWuTOYDztXjZxdE2cIRUa             Opalite             3
# 101   1jgTiNob5cVyXeJ3WgX5bL    Elizabeth Taylor             2
# 337   1qbmS6ep2hbBRaEZFpn7BX          Man I Need             1
# 1134  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER             4
# 103   03bTIHJElXZ0O0jqOQvAbY       Father Figure             4
# 450   02sy7FAs8dkDNYsHp4Ul3f            Soda Pop             3
# 97    5ylJtmaWPJ33cW3En7WOu0                Wood             9
# 96    2TEQvxxQabwLQMqWMg1qGu           Wi$h Li$t             8
# 95    1appZ3c336FkPvCuywfmrs          CANCELLED!            10
#
#       track_popularity  explicit    artist_name  artist_popularity  \
# 457                 99     False        HUNTR/X                 87
# 88                  97     False   Taylor Swift                100
# 101                 95     False   Taylor Swift                100
# 337                 95     False    Olivia Dean                 88
# 1134                94     False  Billie Eilish                 90
# 103                 94      True   Taylor Swift                100
# 450                 94     False      Saja Boys                 80
# 97                  93      True   Taylor Swift                100
# 96                  93      True   Taylor Swift                100
# 95                  93      True   Taylor Swift                100
#
#       artist_followers                          artist_genres  \
# 457            3551538                                  k-pop
# 88           145443567              country, pop, indie, folk
# 101          145489371              country, pop, indie, folk
# 337            1499215                               pop soul
# 1134         118692183  alternative pop, electropop, dark pop
# 103          145542136              country, pop, indie, folk
# 450            2234812                                    NaN
# 97           145443567              country, pop, indie, folk
# 96           145396321              country, pop, indie, folk
# 95           145396321              country, pop, indie, folk
#
#                     album_id  \
# 457   14JkAa6IiFaOh5s0nMyMU9
# 88    4a6NzYL1YHRUgx9e3YZI6I
# 101   4a6NzYL1YHRUgx9e3YZI6I
# 337   0Bv6OJO0L5gcf20DMww54a
# 1134  7aJuG4TFXa2hmE4z1yxc3n
# 103   4a6NzYL1YHRUgx9e3YZI6I
# 450   14JkAa6IiFaOh5s0nMyMU9
# 97    4a6NzYL1YHRUgx9e3YZI6I
# 96    4a6NzYL1YHRUgx9e3YZI6I
# 95    4a6NzYL1YHRUgx9e3YZI6I
#
#                                              album_name album_release_date  \
# 457   KPop Demon Hunters (Soundtrack from the Netfli...         2025-06-20
# 88                               The Life of a Showgirl         2025-10-03
# 101                              The Life of a Showgirl         2025-10-03
# 337                                          Man I Need         2025-08-15
# 1134                               HIT ME HARD AND SOFT         2024-05-17
# 103                              The Life of a Showgirl         2025-10-03
# 450   KPop Demon Hunters (Soundtrack from the Netfli...         2025-06-20
# 97                               The Life of a Showgirl         2025-10-03
# 96                               The Life of a Showgirl         2025-10-03
# 95                               The Life of a Showgirl         2025-10-03
#
#       album_total_tracks album_type  track_duration_min
# 457                   12      album                3.24
# 88                    12      album                3.92
# 101                   12      album                3.47
# 337                    3     single                3.06
# 1134                  10      album                3.50
# 103                   12      album                3.54
# 450                   12      album                2.51
# 97                    12      album                2.50
# 96                    12      album                3.45
# 95                    12      album                3.52

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_number', 'track_popularity',
#        'explicit', 'artist_name', 'artist_popularity', 'artist_followers',
#        'artist_genres', 'album_id', 'album_name', 'album_release_date',
#        'album_total_tracks', 'album_type', 'track_duration_min'],
#       dtype='object')

# %%
df1 = df_sorted.drop(["track_id", "album_id", "track_number"], axis=1)
df1.head()
# Out:
#               track_name  track_popularity  explicit    artist_name  \
# 457               Golden                99     False        HUNTR/X
# 88               Opalite                97     False   Taylor Swift
# 101     Elizabeth Taylor                95     False   Taylor Swift
# 337           Man I Need                95     False    Olivia Dean
# 1134  BIRDS OF A FEATHER                94     False  Billie Eilish
#
#       artist_popularity  artist_followers  \
# 457                  87           3551538
# 88                  100         145443567
# 101                 100         145489371
# 337                  88           1499215
# 1134                 90         118692183
#
#                               artist_genres  \
# 457                                   k-pop
# 88                country, pop, indie, folk
# 101               country, pop, indie, folk
# 337                                pop soul
# 1134  alternative pop, electropop, dark pop
#
#                                              album_name album_release_date  \
# 457   KPop Demon Hunters (Soundtrack from the Netfli...         2025-06-20
# 88                               The Life of a Showgirl         2025-10-03
# 101                              The Life of a Showgirl         2025-10-03
# 337                                          Man I Need         2025-08-15
# 1134                               HIT ME HARD AND SOFT         2024-05-17
#
#       album_total_tracks album_type  track_duration_min
# 457                   12      album                3.24
# 88                    12      album                3.92
# 101                   12      album                3.47
# 337                    3     single                3.06
# 1134                  10      album                3.50

# %%
df1["album_type"].unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
print(df1["album_type"].value_counts())


print(df1["album_type"].value_counts(normalize = True)*100)
# Out:
# album_type
# album          5856
# single         2219
# compilation     507
# Name: count, dtype: int64
# album_type
# album          68.235842
# single         25.856444
# compilation     5.907714
# Name: proportion, dtype: float64

# %%
df1["album_type"] = df1["album_type"].map({"album":2, "single":1, "compilation":0})

# %%
df1["explicit"] = df1["explicit"].map({True:1, False:0})

# %%
df1["album_release_date"] = pd.to_datetime(df1["album_release_date"])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8582 entries, 457 to 0
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_name          8582 non-null   object
#  1   track_popularity    8582 non-null   int64
#  2   explicit            8582 non-null   int64
#  3   artist_name         8579 non-null   object
#  4   artist_popularity   8582 non-null   int64
#  5   artist_followers    8582 non-null   int64
#  6   artist_genres       5221 non-null   object
#  7   album_name          8582 non-null   object
#  8   album_release_date  8582 non-null   datetime64[ns]
#  9   album_total_tracks  8582 non-null   int64
#  10  album_type          8582 non-null   int64
#  11  track_duration_min  8582 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(4)
# memory usage: 871.6+ KB

# %%
df1["album_type"].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
df["explicit"].unique()
# Out:
# array([ True, False])

# %% [markdown]
# ## Assignment 1: Analyze Relationships
# Determining which factors most strongly correlate with a track's success.

# %%
df1_heatmap = df1[["track_popularity", "artist_popularity", "artist_followers", "track_duration_min", "album_total_tracks"]]

# %%
correlation_matrix = df1_heatmap.corr(method="spearman")

sns.heatmap(correlation_matrix, annot=True, fmt=".3f", linewidth=.5, cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# Based on the heatmap we can see there's correlation between artist_popularity and artist_followers
# that is associated with a track gaining in popularity.

# %%
sns.regplot(data=df1, x="artist_popularity", y="track_popularity", color="green", line_kws=dict(color="black"));

plt.savefig("track vs artist popularity.png")

# %% [markdown]
# ## Assignment 2: The Evolution of Music
# Visualizing how music production trends have changed over the decades.

# %%
df1["album_release_date"] = df1["album_release_date"].dt.year

# %%
df1_2009_2025 = (df1["album_release_date"] >=2009) & (df1["album_release_date"] <=2025)

# %%
avg_track_duration = df1[df1_2009_2025].groupby("album_release_date")["track_duration_min"].mean().reset_index()

# %%
volume_of_releases = df1[df1_2009_2025].groupby("album_release_date")["album_release_date"].count()

# %%
figure, ax1 = plt.subplots(figsize=(6,4))
ax2 = ax1.twinx() #Matplotlib function that creates a second y-axis that shares the same x-axis as the main plot.

### Avg. Track Duration
sns.set_style("whitegrid")
sns.lineplot(data=avg_track_duration, x="album_release_date", y="track_duration_min", marker="o",
             color = "green", ax=ax1, label="Avg. Track Duration")

if ax1.legend_: #Removes seaborn auto legend
    ax1.legend_.remove()
ax1.set_xlabel("Album Release")
ax1.set_ylabel("Avg. Track Duration(minutes)")


sns.lineplot(data=volume_of_releases, marker="o",
             color = "black", ax=ax2, label="Volume of Releases")

plt.title("Evolution of Music (2009-2025)")

if ax2.legend_: #Removes seaborn auto legend
    ax2.legend_.remove()
ax2.set_xlabel("Album Release")
ax2.set_ylabel("Volume of Releases")

# Manually creating the legend
lines = ax1.get_lines() + ax2.get_lines()
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc="center left")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Assignment 3: Genres
# Identifying the most prevalent genres.

# %%
df1.head()
# Out:
#               track_name  track_popularity  explicit    artist_name  \
# 457               Golden                99         0        HUNTR/X
# 88               Opalite                97         0   Taylor Swift
# 101     Elizabeth Taylor                95         0   Taylor Swift
# 337           Man I Need                95         0    Olivia Dean
# 1134  BIRDS OF A FEATHER                94         0  Billie Eilish
#
#       artist_popularity  artist_followers  \
# 457                  87           3551538
# 88                  100         145443567
# 101                 100         145489371
# 337                  88           1499215
# 1134                 90         118692183
#
#                               artist_genres  \
# 457                                   k-pop
# 88                country, pop, indie, folk
# 101               country, pop, indie, folk
# 337                                pop soul
# 1134  alternative pop, electropop, dark pop
#
#                                              album_name  album_release_date  \
# 457   KPop Demon Hunters (Soundtrack from the Netfli...                2025
# 88                               The Life of a Showgirl                2025
# 101                              The Life of a Showgirl                2025
# 337                                          Man I Need                2025
# 1134                               HIT ME HARD AND SOFT                2024
#
#       album_total_tracks  album_type  track_duration_min
# 457                   12           2                3.24
# 88                    12           2                3.92
# 101                   12           2                3.47
# 337                    3           1                3.06
# 1134                  10           2                3.50

# %%
df1_genres = df1.dropna(subset="artist_genres", axis=0)

# %%
# .str.split() breaks a string into a list of substrings based on a specified delimiter
df1_genres["artist_genres"] = df1_genres["artist_genres"].str.split(", ")

# .explode() used with pandas library, transforms each element of a list-like column into a separate row
df1_genres = df1_genres.explode("artist_genres")

# %%
df1_genre_count = df1_genres["artist_genres"].value_counts().head(15)

# %%
plt.figure(figsize=(15,6))

sns.set_style("whitegrid")
sns.barplot(data=df1_genre_count, color = "green")

plt.title("Top 15 Genres")
plt.xlabel("Genres")
plt.ylabel("Count")

plt.show();

# %% [markdown]
# ## Assignment 4: Content & Formatting
# Comparing how different types of releases perform.

# %%
sns.boxplot(data=df, x="track_popularity", y="album_type", orient="h", hue = "album_type",
           width=.5)

plt.title("Album vs. Single vs. Compilation")
plt.xlabel("Track Popularity")
plt.ylabel("Album Type")

plt.show();

# %%
df["album_type"].value_counts()
# Out:
# album_type
# album          5856
# single         2219
# compilation     507
# Name: count, dtype: int64

# %%
df_explicit = df.groupby("explicit")["track_popularity"].mean()

# %%
sns.barplot(data=df_explicit, color = "green", order=[True,False])

plt.title("Average Track Popularity: Explicit vs. Non-Explicit")
plt.xticks([True,False], ["Non-Explicit","Explicit"])
plt.xlabel("")
plt.ylabel("Track Popularity")

plt.show();
